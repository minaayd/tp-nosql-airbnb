# %% [markdown]
# # TP NoSQL
#
# Prénom :
#
# Nom :
#
# Pour ce TP noté vous avez à trois heures pour le réaliser et 48 heures pour le finir si besoin. Le rendu final est attendu pour dimanche 29 septembre 2024 à 23 h 59.
#
# Vous serrez évalués sur les requêtes mais également sur la qualité et la propreté du code. Pour chaque question, une réponse présentant les résultats est attendue.

# %%
# installation des packages pandas et pymongo
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter==1.1.0 in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: pandas==2.2.3 in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: pymongo==4.9.1 in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: notebook in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (7.0.8)
# Requirement already satisfied: jupyter-console in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (7.10.0)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (7.6.5)
# Requirement already satisfied: jupyterlab in c:\programdata\anaconda3\lib\site-packages (from jupyter==1.1.0->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: numpy>=1.23.2 in c:\programdata\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from pymongo==4.9.1->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.1.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.1.0->-r requirements.txt (line 1)) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.1.0->-r requirements.txt (line 1)) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->jupyter==1.1.0->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from jupyter-console->jupyter==1.1.0->-r requirements.txt (line 1)) (3.0.43)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from jupyter-console->jupyter==1.1.0->-r requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: jinja2>=3.0.3 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: notebook-shim>=0.2 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: overrides in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: pywinpty in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: websocket-client in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.58.0)
# Requirement already satisfied: babel>=2.10 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter==1.1.0->-r requirements.txt (line 1)) (2.16.2)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.1.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.1.0->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.19.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2024.6.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.0->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\programdata\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.1)
# Requirement already satisfied: uri-template in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\mina.aydogmus\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.0->-r requirements.txt (line 1)) (1.2.3)

# %%
import pymongo
import pandas as pd

URI = 'mongodb+srv://mongo_user:KoB9Xy6d0ADEdMwz@cluster-but-sd.nvq0y.mongodb.net/?retryWrites=true&w=majority&appName=cluster-but-sd'
client = pymongo.MongoClient(URI)
db = client.tp

# output the name of the collections in the database
print("Collections: ", db.list_collection_names())
# Out:
# Collections:  ['airbnb', 'restaurants']

# %% [markdown]
# 1. Combien de logements sont la base de données ?

# %%
print(db.airbnb.count_documents({}))
#Nous trouvons 5555 logements dans la base de données
# Out:
# 5555

# %% [markdown]
# 2. Quel est le prix moyen par ville ? Trier les villes par prix décroissant.

# %%
px_moyen_ville = db.airbnb.aggregate([
    {"$group": {"_id": "$address.market", "prix_moyen": {"$avg": "$price"}}},
    {"$sort": {"prix_moyen": -1}}
])
pd.DataFrame(list(px_moyen_ville))
#La ville la plus chère est Hong Kong et la moins chère Porto
#Le prix moyen par ville est de:
#_id	prix_moyen
#0	Hong Kong	762.4781906300484652665589660743134
#1	Rio De Janeiro	525.8059701492537313432835820895522
#2	Other (International)	445.75
#3	Istanbul	367.9454545454545454545454545454545
#4	Kauai	288.8208955223880597014925373134328
#5	Maui	286.5882352941176470588235294117647
#6	Oahu	212.2964426877470355731225296442688
#7	Sydney	197.7142857142857142857142857142857
#8	The Big Island	179.4604316546762589928057553956835
#9	New York	139.6260296540362438220757825370675
#10	Other (Domestic)	128.00
#11		115.50
#12	Barcelona	100.9477848101265822784810126582278
#13	Montreal	100.2330246913580246913580246913580
#14	Porto	69.12815884476534296028880866425993
# Out:
#                       _id                           prix_moyen
# 0               Hong Kong  762.4781906300484652665589660743134
# 1          Rio De Janeiro  525.8059701492537313432835820895522
# 2   Other (International)                               445.75
# 3                Istanbul  367.9454545454545454545454545454545
# 4                   Kauai  288.8208955223880597014925373134328
# 5                    Maui  286.5882352941176470588235294117647
# 6                    Oahu  212.2964426877470355731225296442688
# 7                  Sydney  197.7142857142857142857142857142857
# 8          The Big Island  179.4604316546762589928057553956835
# 9                New York  139.6260296540362438220757825370675
# 10       Other (Domestic)                               128.00
# 11                                                      115.50
# 12              Barcelona  100.9477848101265822784810126582278
# 13               Montreal  100.2330246913580246913580246913580
# 14                  Porto  69.12815884476534296028880866425993

# %% [markdown]
# 3. Afficher la liste de tous les différents équipements qui existent.

# %%
equip = db.airbnb.distinct(key="amenities")
print(equip)

#Voici la liste des différents équipements qui existent
#['', '24-hour check-in', 'Accessible-height bed', 'Accessible-height toilet', 'Air conditioning', 'Air purifier', 'Alfresco shower', 
#'BBQ grill', 'Baby bath', 'Baby monitor', 'Babysitter recommendations', 'Balcony', 'Bath towel', 'Bathroom essentials', 'Bathtub', 
#'Bathtub with bath chair', 'Beach chairs', 'Beach essentials', 'Beach view', 'Beachfront', 'Bed linens', 'Bedroom comforts', 'Bicycle', 'Bidet', 
#'Body soap', 'Boogie boards', 'Breakfast', 'Breakfast bar', 'Breakfast table', 'Building staff', 'Buzzer/wireless intercom', 'Cable TV', 
#'Carbon monoxide detector', 'Cat(s)', 'Ceiling fan', 'Central air conditioning', 'Changing table', "Chef's kitchen", 'Children’s books and toys', 
#'Children’s dinnerware', 'Cleaning before checkout', 'Coffee maker', 'Convection oven', 'Cooking basics', 'Crib', 'DVD player', 'Day bed', 
#'Dining area', 'Disabled parking spot', 'Dishes and silverware', 'Dishwasher', 'Dog(s)', 'Doorman', 'Double oven', 'Dryer', 'EV charger', 
#'Electric profiling bed', 'Elevator', 'En suite bathroom', 'Espresso machine', 'Essentials', 'Ethernet connection', 'Extra pillows and blankets', 
#'Family/kid friendly', 'Fax machine', 'Fire extinguisher', 'Fireplace guards', 'Firm mattress', 'First aid kit', 'Fixed grab bars for shower', 
#'Fixed grab bars for toilet', 'Flat path to front door', 'Formal dining area', 'Free parking on premises', 'Free street parking', 'Full kitchen', 
#'Game console', 'Garden or backyard', 'Gas oven', 'Ground floor access', 'Gym', 'Hair dryer', 'Handheld shower head', 'Hangers', 'Heated towel rack', 
#'Heating', 'High chair', 'Home theater', 'Host greets you', 'Hot tub', 'Hot water', 'Hot water kettle', 'Ice Machine', 'Indoor fireplace', 
#'Internet', 'Iron', 'Ironing Board', 'Kayak', 'Keypad', 'Kitchen', 'Kitchenette', 'Lake access', 'Laptop friendly workspace', 'Lock on bedroom door', 
#'Lockbox', 'Long term stays allowed', 'Luggage dropoff allowed', 'Memory foam mattress', 'Microwave', 'Mini fridge', 'Mountain view', 'Murphy bed', 
#'Netflix', 'Other', 'Other pet(s)', 'Outdoor parking', 'Outdoor seating', 'Outlet covers', 'Oven', 'Pack ’n Play/travel crib', 
#'Paid parking off premises', 'Paid parking on premises', 'Parking', 'Patio or balcony', 'Permit parking', 'Pets allowed', 'Pets live on this property', 
#'Pillow-top mattress', 'Pocket wifi', 'Pool', 'Pool with pool hoist', 'Private bathroom', 'Private entrance', 'Private hot tub', 'Private living room', 
#'Private pool', 'Rain shower', 'Refrigerator', 'Roll-in shower', 'Room-darkening shades', 'Safe', 'Safety card', 'Sauna', 'Self check-in', 'Shampoo', 
#'Shared pool', 'Shower chair', 'Single level home', 'Ski-in/Ski-out', 'Smart TV', 'Smart lock', 'Smoke detector', 'Smoking allowed', 
#'Snorkeling equipment', 'Sonos sound system', 'Sound system', 'Stair gates', 'Standing valet', 'Step-free access', 'Stove', 'Suitable for events', 
#'Sun loungers', 'Swimming pool', 'TV', 'Table corner guards', 'Tennis court', 'Terrace', 'Toaster', 'Toilet paper', 'Walk-in shower', 'Warming drawer', 
#'Washer', 'Washer / Dryer', 'Waterfront', 'Well-lit path to entrance', 'Wheelchair accessible', 'Wide clearance to bed', 'Wide clearance to shower', 
#'Wide doorway', 'Wide entryway', 'Wide hallway clearance', 'Wifi', 'Window guards', 'toilet', 'translation missing: en.hosting_amenity_49', 
#'translation missing: en.hosting_amenity_50']
# Out:
# ['', '24-hour check-in', 'Accessible-height bed', 'Accessible-height toilet', 'Air conditioning', 'Air purifier', 'Alfresco shower', 'BBQ grill', 'Baby bath', 'Baby monitor', 'Babysitter recommendations', 'Balcony', 'Bath towel', 'Bathroom essentials', 'Bathtub', 'Bathtub with bath chair', 'Beach chairs', 'Beach essentials', 'Beach view', 'Beachfront', 'Bed linens', 'Bedroom comforts', 'Bicycle', 'Bidet', 'Body soap', 'Boogie boards', 'Breakfast', 'Breakfast bar', 'Breakfast table', 'Building staff', 'Buzzer/wireless intercom', 'Cable TV', 'Carbon monoxide detector', 'Cat(s)', 'Ceiling fan', 'Central air conditioning', 'Changing table', "Chef's kitchen", 'Children’s books and toys', 'Children’s dinnerware', 'Cleaning before checkout', 'Coffee maker', 'Convection oven', 'Cooking basics', 'Crib', 'DVD player', 'Day bed', 'Dining area', 'Disabled parking spot', 'Dishes and silverware', 'Dishwasher', 'Dog(s)', 'Doorman', 'Double oven', 'Dryer', 'EV charger', 'Electric profiling bed', 'Elevator', 'En suite bathroom', 'Espresso machine', 'Essentials', 'Ethernet connection', 'Extra pillows and blankets', 'Family/kid friendly', 'Fax machine', 'Fire extinguisher', 'Fireplace guards', 'Firm mattress', 'First aid kit', 'Fixed grab bars for shower', 'Fixed grab bars for toilet', 'Flat path to front door', 'Formal dining area', 'Free parking on premises', 'Free street parking', 'Full kitchen', 'Game console', 'Garden or backyard', 'Gas oven', 'Ground floor access', 'Gym', 'Hair dryer', 'Handheld shower head', 'Hangers', 'Heated towel rack', 'Heating', 'High chair', 'Home theater', 'Host greets you', 'Hot tub', 'Hot water', 'Hot water kettle', 'Ice Machine', 'Indoor fireplace', 'Internet', 'Iron', 'Ironing Board', 'Kayak', 'Keypad', 'Kitchen', 'Kitchenette', 'Lake access', 'Laptop friendly workspace', 'Lock on bedroom door', 'Lockbox', 'Long term stays allowed', 'Luggage dropoff allowed', 'Memory foam mattress', 'Microwave', 'Mini fridge', 'Mountain view', 'Murphy bed', 'Netflix', 'Other', 'Other pet(s)', 'Outdoor parking', 'Outdoor seating', 'Outlet covers', 'Oven', 'Pack ’n Play/travel crib', 'Paid parking off premises', 'Paid parking on premises', 'Parking', 'Patio or balcony', 'Permit parking', 'Pets allowed', 'Pets live on this property', 'Pillow-top mattress', 'Pocket wifi', 'Pool', 'Pool with pool hoist', 'Private bathroom', 'Private entrance', 'Private hot tub', 'Private living room', 'Private pool', 'Rain shower', 'Refrigerator', 'Roll-in shower', 'Room-darkening shades', 'Safe', 'Safety card', 'Sauna', 'Self check-in', 'Shampoo', 'Shared pool', 'Shower chair', 'Single level home', 'Ski-in/Ski-out', 'Smart TV', 'Smart lock', 'Smoke detector', 'Smoking allowed', 'Snorkeling equipment', 'Sonos sound system', 'Sound system', 'Stair gates', 'Standing valet', 'Step-free access', 'Stove', 'Suitable for events', 'Sun loungers', 'Swimming pool', 'TV', 'Table corner guards', 'Tennis court', 'Terrace', 'Toaster', 'Toilet paper', 'Walk-in shower', 'Warming drawer', 'Washer', 'Washer / Dryer', 'Waterfront', 'Well-lit path to entrance', 'Wheelchair accessible', 'Wide clearance to bed', 'Wide clearance to shower', 'Wide doorway', 'Wide entryway', 'Wide hallway clearance', 'Wifi', 'Window guards', 'toilet', 'translation missing: en.hosting_amenity_49', 'translation missing: en.hosting_amenity_50']

# %% [markdown]
# 4. Combien de propriétés incluent le Wifi dans les équipements ?

# %%
ppt_wifi = db.airbnb.count_documents({"amenities": "Wifi"})
ppt_wifi
#5303 des logements Airbnb ont du wifi dans leurs équipements
# Out:
# 5303

# %% [markdown]
# 5. Afficher le nom de tous les logements ainsi que le nombre de chambres et de lits qu'ils contiennent (ne pas afficher l'ID)

# %%
all = db.airbnb.find({}, {"_id": 0, "name": 1 , "bedrooms": 1, "beds": 1})
print(pd.DataFrame(list(all)))
# Out:
#                                                   name  bedrooms  beds
# 0                          Apt Linda Vista Lagoa - Rio       1.0   1.0
# 1                   Ótimo Apto proximo Parque Olimpico       2.0   2.0
# 2                       Modern Spacious 1 Bedroom Loft       1.0   2.0
# 3     Ligne verte - à 15 min de métro du centre ville.       0.0   1.0
# 4                              Ribeira Charming Duplex       3.0   5.0
# ...                                                ...       ...   ...
# 5550     Estudio en el casco antiguo. Alquiler mensual       0.0   3.0
# 5551  Qto Aconchegante no em frente ao Parque Olímpico       1.0   1.0
# 5552                  StayIN Oporto Música - Apartment       8.0   8.0
# 5553                                      Quarto Legal       1.0   1.0
# 5554                                                         1.0   1.0
#
# [5555 rows x 3 columns]

# %% [markdown]
# 6. Afficher le nom et le prix des logements situés à Porto.

# %%
porto = db.airbnb.find({"address.market": "Porto"}, {"_id": 0, "name": 1, "price": 1})
print(pd.DataFrame(list(porto)))
#La base de données des logements à Porto contient 554 lignes.
#Voici le résultat du tableau affichant le nom et le prix des logements situé à Porto
#                              name   price
#0                Ribeira Charming Duplex   80.00
#1                      Be Happy in Porto   30.00
#2    Downtown Oporto Inn (room cleaning)   40.00
#3                         FloresRooms 3T   31.00
#4     A Casa Alegre é um apartamento T1.   40.00
#..                                   ...     ...
#549         Number283 - Your home abroad   48.00
#550        Cozy apartment downtown Porto   58.00
#551                   Soares Guest House   90.00
#552   Central, Modern, University, Metro   41.00
#553     StayIN Oporto Música - Apartment  500.00

#[554 rows x 2 columns]
# Out:
#                                     name   price
# 0                Ribeira Charming Duplex   80.00
# 1                      Be Happy in Porto   30.00
# 2    Downtown Oporto Inn (room cleaning)   40.00
# 3                         FloresRooms 3T   31.00
# 4     A Casa Alegre é um apartamento T1.   40.00
# ..                                   ...     ...
# 549         Number283 - Your home abroad   48.00
# 550        Cozy apartment downtown Porto   58.00
# 551                   Soares Guest House   90.00
# 552   Central, Modern, University, Metro   41.00
# 553     StayIN Oporto Música - Apartment  500.00
#
# [554 rows x 2 columns]

# %% [markdown]
# 7. Quels sont les 5 hôtes les plus populaires (ceux dont les propriétés ont reçu le plus de commentaires) ?

# %%
popu = db.airbnb.aggregate([{"$group": {"_id": "name", "nb_com": {"$sortByCount": "reviews"}}},{"$sort": {"nb_com": -1}}, {"$limit": 5}])
pd.DataFrame(list(popu))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 popu = db.airbnb.aggregate([{"$group": {"_id": "name", "nb_com": {"$sortByCount": "reviews"}}},{"$sort": {"nb_com": -1}}, {"$limit": 5}])
#       2 pd.DataFrame(list(popu))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\collection.py:2937, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2861 """Perform an aggregation using the aggregation framework on this
#    2862 collection.
#    2863
#    (...)
#    2934     https://mongodb.com/docs/manual/reference/command/aggregate
#    2935 """
#    2936 with self._database.client._tmp_session(session, close=False) as s:
# -> 2937     return self._aggregate(
#    2938         _CollectionAggregationCommand,
#    2939         pipeline,
#    2940         CommandCursor,
#    2941         session=s,
#    2942         explicit_session=session is not None,
#    2943         let=let,
#    2944         comment=comment,
#    2945         **kwargs,
#    2946     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\collection.py:2845, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2834     kwargs["comment"] = comment
#    2835 cmd = aggregation_command(
#    2836     self,
#    2837     cursor_class,
#    (...)
#    2842     user_fields={"cursor": {"firstBatch": 1}},
#    2843 )
# -> 2845 return self._database.client._retryable_read(
#    2846     cmd.get_cursor,
#    2847     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2848     session,
#    2849     retryable=not cmd._performs_write,
#    2850     operation=_Op.AGGREGATE,
#    2851 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: unknown group operator '$sortByCount', full error: {'ok': 0.0, 'errmsg': "unknown group operator '$sortByCount'", 'code': 15952, 'codeName': 'Location15952', '$clusterTime': {'clusterTime': Timestamp(1727427019, 5), 'signature': {'hash': b'\x8e\x03\x80p\x97\xa1T\xc7\xc5\x89h\x8d\x97\x15SQ\xd9\xbaw\xb2', 'keyId': 7354431230047158275}}, 'operationTime': Timestamp(1727427019, 5)}

# %% [markdown]
# 8. Quelles sont les 6 villes ayant le plus de logements disponibles à la location ?

# %%
dispo = db.airbnb.aggregate([
    {"$group": {
        "_id": "$address.market",
        "nb_dispo": {"$sum": 1}
    }},
    {"$sort": {"nb_dispo": -1}},
    {"$limit": 6}
])
pd.DataFrame(list(dispo))

#La ville ayant le plus de logements disponibles à la location est Istanbul avec 660 logements disponibles
# Out:
#          _id  nb_dispo
# 0   Istanbul       660
# 1   Montreal       648
# 2  Barcelona       632
# 3  Hong Kong       619
# 4     Sydney       609
# 5   New York       607

# %% [markdown]
# 9. Combien de propriétés acceptent plus de 4 invités et ont une caution de moins de 300€ ?

# %%
ppt_4_300 = db.airbnb.count_documents({"price": {"$lt": 300}, "security_deposit": {"$gt": 4}})
print(ppt_4_300)
#Il existe 1685 logements acceptant plus de 4 invités et une caution de moins de 300€
# Out:
# 1685

# %% [markdown]
# 10. Donner les 20 utilisateurs qui ont fait le plus de commentaires (afficher seulement l'ID et le nom de l'utilisateur).

# %%
com = db.airbnb.aggregate([
    {"$unwind": "$reviews"},
    {"$group": {
        "_id": {"id": "$reviews.reviewer_id","nom":"$reviews.reviewer_name"},
        "nb_com_eff": {"$sum": 1}
    }},
    {"$sort": {"nb_com_eff": -1}},
    {"$limit": 20},
    {"$project": {
        "_id.id": 1,
        "_id.nom":1
    }}
])

print(pd.DataFrame(list(com)))

#Filipe est l'utilisateur ayant mis le plus de commentaires et Pierre le moins
# Out:
#                                       _id
# 0     {'id': '20775242', 'nom': 'Filipe'}
# 1       {'id': '67084875', 'nom': 'Nick'}
# 2         {'id': '2961855', 'nom': 'Uge'}
# 3     {'id': '162027327', 'nom': 'Thien'}
# 4       {'id': '20991911', 'nom': 'Lisa'}
# 5       {'id': '69140895', 'nom': 'Lisa'}
# 6       {'id': '12679057', 'nom': 'Jodi'}
# 7   {'id': '55241576', 'nom': 'Courtney'}
# 8       {'id': '60816198', 'nom': 'Todd'}
# 9       {'id': '1705870', 'nom': 'David'}
# 10     {'id': '78093968', 'nom': 'David'}
# 11     {'id': '47303133', 'nom': 'Lance'}
# 12      {'id': '57325457', 'nom': 'Mary'}
# 13     {'id': '25715809', 'nom': 'Megan'}
# 14      {'id': '61469899', 'nom': 'Erik'}
# 15     {'id': '76782210', 'nom': 'Assis'}
# 16  {'id': '128210181', 'nom': 'Branden'}
# 17     {'id': '86665925', 'nom': 'Chris'}
# 18       {'id': '34005800', 'nom': 'Dan'}
# 19    {'id': '93859831', 'nom': 'Pierre'}

# %% [markdown]
# 11. Parmi les logements à Sydney, quel est la note moyenne des visiteurs ?

# %%
syd = db.airbnb.aggregate([
    {"$match": {"$address.market": "Sydney"}},
    {"$unwind": "review_scores."},
    {"$group": 
         {"_id": "$address.market", "note_moy": {"$avg": "$review_scores.review_scores_rating"}}}
    ])

print(pd.DataFrame(list(syd)))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 syd = db.airbnb.aggregate([
#       2     {"$match": {"$address.market": "Sydney"}},
#       3     {"$unwind": "review_scores."},
#       4     {"$group":
#       5          {"_id": "$address.market", "note_moy": {"$avg": "$review_scores.review_scores_rating"}}}
#       6     ])
#       8 print(pd.DataFrame(list(syd)))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\collection.py:2937, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2861 """Perform an aggregation using the aggregation framework on this
#    2862 collection.
#    2863
#    (...)
#    2934     https://mongodb.com/docs/manual/reference/command/aggregate
#    2935 """
#    2936 with self._database.client._tmp_session(session, close=False) as s:
# -> 2937     return self._aggregate(
#    2938         _CollectionAggregationCommand,
#    2939         pipeline,
#    2940         CommandCursor,
#    2941         session=s,
#    2942         explicit_session=session is not None,
#    2943         let=let,
#    2944         comment=comment,
#    2945         **kwargs,
#    2946     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\collection.py:2845, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2834     kwargs["comment"] = comment
#    2835 cmd = aggregation_command(
#    2836     self,
#    2837     cursor_class,
#    (...)
#    2842     user_fields={"cursor": {"firstBatch": 1}},
#    2843 )
# -> 2845 return self._database.client._retryable_read(
#    2846     cmd.get_cursor,
#    2847     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2848     session,
#    2849     retryable=not cmd._performs_write,
#    2850     operation=_Op.AGGREGATE,
#    2851 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\mongo_client.py:2697, in _ClientConnectionRetryable._read(self)
#    2695 if self._retrying and not self._retryable:
#    2696     self._check_last_error()
# -> 2697 return self._func(self._session, self._server, conn, read_pref)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: unknown top level operator: $address.market. If you have a field name that starts with a '$' symbol, consider using $getField or $setField., full error: {'ok': 0.0, 'errmsg': "unknown top level operator: $address.market. If you have a field name that starts with a '$' symbol, consider using $getField or $setField.", 'code': 2, 'codeName': 'BadValue', '$clusterTime': {'clusterTime': Timestamp(1727430078, 7), 'signature': {'hash': b'|\x8f\x94\xc0\xe4\x1d\xcd5057\x04ZZK\x93\xf0\xe1_\xfb', 'keyId': 7354431230047158275}}, 'operationTime': Timestamp(1727430078, 7)}

# %% [markdown]
# 12. (bonus) Afficher les logements qui contiennent le mot "park" dans leur nom

# %%
park = db.airbnb.find({"name": {"$regex": "park"}}, {})
print(pd.DataFrame(list(park)))
#Nous avons 47 logements contenant le mot "park"
# Out:
#          _id                            listing_url  \
# 0    1070322   https://www.airbnb.com/rooms/1070322
# 1   10416859  https://www.airbnb.com/rooms/10416859
# 2   12774820  https://www.airbnb.com/rooms/12774820
# 3   13227163  https://www.airbnb.com/rooms/13227163
# 4   13852692  https://www.airbnb.com/rooms/13852692
# 5   13875927  https://www.airbnb.com/rooms/13875927
# 6   15206608  https://www.airbnb.com/rooms/15206608
# 7   15119850  https://www.airbnb.com/rooms/15119850
# 8   15808180  https://www.airbnb.com/rooms/15808180
# 9   15997148  https://www.airbnb.com/rooms/15997148
# 10  16261574  https://www.airbnb.com/rooms/16261574
# 11  18599539  https://www.airbnb.com/rooms/18599539
# 12  19337464  https://www.airbnb.com/rooms/19337464
# 13  19254909  https://www.airbnb.com/rooms/19254909
# 14  18707992  https://www.airbnb.com/rooms/18707992
# 15  19680142  https://www.airbnb.com/rooms/19680142
# 16  19963866  https://www.airbnb.com/rooms/19963866
# 17  21451259  https://www.airbnb.com/rooms/21451259
# 18  21536635  https://www.airbnb.com/rooms/21536635
# 19  22265304  https://www.airbnb.com/rooms/22265304
# 20  23149443  https://www.airbnb.com/rooms/23149443
# 21  23109052  https://www.airbnb.com/rooms/23109052
# 22  24675658  https://www.airbnb.com/rooms/24675658
# 23  24579565  https://www.airbnb.com/rooms/24579565
# 24  25148829  https://www.airbnb.com/rooms/25148829
# 25  25398833  https://www.airbnb.com/rooms/25398833
# 26  26565457  https://www.airbnb.com/rooms/26565457
# 27  26948900  https://www.airbnb.com/rooms/26948900
# 28  27983285  https://www.airbnb.com/rooms/27983285
# 29  26849639  https://www.airbnb.com/rooms/26849639
# 30   3029260   https://www.airbnb.com/rooms/3029260
# 31  30325676  https://www.airbnb.com/rooms/30325676
# 32  29108266  https://www.airbnb.com/rooms/29108266
# 33  30533458  https://www.airbnb.com/rooms/30533458
# 34  29982730  https://www.airbnb.com/rooms/29982730
# 35  30515970  https://www.airbnb.com/rooms/30515970
# 36  30538139  https://www.airbnb.com/rooms/30538139
# 37  32715595  https://www.airbnb.com/rooms/32715595
# 38  32835270  https://www.airbnb.com/rooms/32835270
# 39   5837702   https://www.airbnb.com/rooms/5837702
# 40   6358160   https://www.airbnb.com/rooms/6358160
# 41   6626223   https://www.airbnb.com/rooms/6626223
# 42   7718248   https://www.airbnb.com/rooms/7718248
# 43   8427787   https://www.airbnb.com/rooms/8427787
# 44   9802077   https://www.airbnb.com/rooms/9802077
# 45   9612902   https://www.airbnb.com/rooms/9612902
# 46   9810515   https://www.airbnb.com/rooms/9810515
#
#                                                  name        room_type  \
# 0                    Triple room Barcelona Guell park     Private room
# 1   Studio convenient to CBD, beaches, street park...  Entire home/apt
# 2                   Lachine room+Free parking+Airport     Private room
# 3                Apartment in the centre with parking  Entire home/apt
# 4      VERY LARGE 5 Bedroom Home, free onsite parking  Entire home/apt
# 5          TPC - Flying Leaves Balcony (free parking)  Entire home/apt
# 6   Bright,cozy,quiet,walking distance metro,park ...  Entire home/apt
# 7                   Apartment located near Guell park     Private room
# 8    Private Studio closed to town w/ compact parking  Entire home/apt
# 9   Huge kid-friendly Brooklyn home with parking/p...  Entire home/apt
# 10                     Amazing view Apt@ Olympic park  Entire home/apt
# 11              Luxury condo with free indoor parking  Entire home/apt
# 12  Bright & spacious 2 bed near Molson Park w/par...  Entire home/apt
# 13        Newly renovated cosy apartment with parking  Entire home/apt
# 14  Clean, bright & cozy bedroom /w convenient par...     Private room
# 15  Best location downtown + free parking - Esperanza  Entire home/apt
# 16          Palacio Garden's Apartment (Free parking)  Entire home/apt
# 17   Close to park and sea: Light and airy family apt  Entire home/apt
# 18             Charming apartment facing Laurier park  Entire home/apt
# 19            Manly Haven- Best Location with carpark  Entire home/apt
# 20      MILE-END ☀️Near MONTROYAL park☀️ FREE PARKING  Entire home/apt
# 21    7 guests at ville St-Laurent, with parking spot  Entire home/apt
# 22  Your place for Sea, Cellars & Porto! (parking ...  Entire home/apt
# 23                 Repos de Ouro  Street of city park  Entire home/apt
# 24  Terrace- park view, great location, quiet street.  Entire home/apt
# 25     Free parking free laundry at Dabin's Cozy Home     Private room
# 26        Maison de ville parking et à 2 pas du métro     Private room
# 27                 Homa 2 - 1 BR sleep 4 parking - AC  Entire home/apt
# 28   Amazing location, room for 3, w. private parking     Private room
# 29   Super bright apartment in quiet area facing park  Entire home/apt
# 30              Lovely apartment with private parking  Entire home/apt
# 31  Renovated sunny 3 Bedroom apartment - easy par...  Entire home/apt
# 32    Quiet spacious 1 bedroom apartment with parking  Entire home/apt
# 33     Penthouse Downtown with private indoor parking  Entire home/apt
# 34                 A Antiga Adega (parking available)  Entire home/apt
# 35    Luxury 2 bed 2 bath 1 parking in Allure Waikiki  Entire home/apt
# 36  Freshly renovated-3 bedroom-heart of MTL-parki...  Entire home/apt
# 37    Quiet house with parking near downtown Montreal  Entire home/apt
# 38      Lux 2 bedroom/2 bath/2 balconies/free parking  Entire home/apt
# 39                          2 Bedroom -guest parking.  Entire home/apt
# 40                     Lovely home with parking spot!  Entire home/apt
# 41            2 bedroom + 1 sofa, free car park place  Entire home/apt
# 42                4BR family home nr beaches and park  Entire home/apt
# 43       4 bedroom home W/diamond head view w/parking  Entire home/apt
# 44  Sydney Studio in Glebe Close to CBD. SparklinC...  Entire home/apt
# 45  1921 15kms from Sydney CBD with Pool Spa parking.  Entire home/apt
# 46                  Big 2bdm, Views, WIFI and carpark  Entire home/apt
#
#     accommodates  bedrooms  beds bathrooms  \
# 0              3         1     3       1.0
# 1              5         1     4       1.0
# 2              3         1     1       1.0
# 3              3         1     1       1.0
# 4             10         5     6       3.0
# 5              4         2     2       1.0
# 6              4         2     2       1.0
# 7              2         1     2       1.0
# 8              3         0     1       1.0
# 9              4         2     3       2.5
# 10             5         1     2       1.0
# 11             4         0     1       1.0
# 12             4         2     2       1.0
# 13             2         1     1       1.0
# 14             1         1     1       1.0
# 15             6         1     3       1.0
# 16             4         1     2       1.0
# 17             5         2     3       1.0
# 18             2         1     1       1.0
# 19             4         2     3       2.0
# 20            12         5     7       1.0
# 21             7         2     3       1.0
# 22             6         2     4       1.5
# 23             6         3     4       2.0
# 24             4         2     2       1.5
# 25             2         1     1       1.0
# 26             2         1     1       1.0
# 27             4         1     2       1.0
# 28             3         1     2       1.0
# 29             6         2     3       1.0
# 30             5         1     1       1.0
# 31             6         3     3       1.0
# 32             3         1     2       1.0
# 33             6         2     2       2.0
# 34             4         2     2       1.0
# 35             4         2     2       2.0
# 36             6         3     3       1.0
# 37             6         2     4       1.0
# 38             5         2     3       2.0
# 39             4         2     2       1.0
# 40             5         2     2       1.0
# 41             4         2     2       0.0
# 42             7         4     7       2.0
# 43             6         4     4       2.5
# 44             2         1     1       1.0
# 45             9         5     5       3.0
# 46             4         2     3       1.0
#
#                                             amenities   price  \
# 0   [Wifi, Paid parking off premises, Pets live on...   40.00
# 1   [TV, Cable TV, Wifi, Air conditioning, Kitchen...   45.00
# 2   [TV, Internet, Wifi, Air conditioning, Wheelch...   78.00
# 3   [TV, Cable TV, Wifi, Kitchen, Free parking on ...   55.00
# 4   [TV, Internet, Wifi, Air conditioning, Kitchen...  550.00
# 5   [TV, Cable TV, Internet, Wifi, Air conditionin...   60.00
# 6   [TV, Internet, Wifi, Kitchen, Free street park...   58.00
# 7   [Wifi, Pets live on this property, Essentials,...   31.00
# 8   [TV, Internet, Wifi, Air conditioning, Kitchen...   95.00
# 9   [Internet, Wifi, Air conditioning, Kitchen, Fr...  150.00
# 10  [TV, Wifi, Air conditioning, Kitchen, Free par...  159.00
# 11  [TV, Cable TV, Wifi, Air conditioning, Pool, K...   94.00
# 12  [Wifi, Kitchen, Free parking on premises, Heat...  101.00
# 13  [Wifi, Pool, Kitchen, Free parking on premises...  115.00
# 14  [Wifi, Free parking on premises, Heating, Fami...   50.00
# 15  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...   67.00
# 16  [TV, Wifi, Air conditioning, Kitchen, Elevator...   39.00
# 17  [TV, Wifi, Kitchen, Free street parking, Heati...  181.00
# 18  [Wifi, Kitchen, Free parking on premises, Heat...   60.00
# 19  [TV, Wifi, Kitchen, Free parking on premises, ...  220.00
# 20  [TV, Wifi, Air conditioning, Kitchen, Free par...  150.00
# 21  [TV, Wifi, Kitchen, Free parking on premises, ...   95.00
# 22  [TV, Cable TV, Wifi, Kitchen, Free parking on ...   63.00
# 23  [TV, Wifi, Kitchen, Free parking on premises, ...  120.00
# 24  [TV, Wifi, Air conditioning, Kitchen, Free par...  112.00
# 25  [TV, Wifi, Air conditioning, Kitchen, Free par...   39.00
# 26  [TV, Cable TV, Internet, Wifi, Air conditionin...   55.00
# 27  [TV, Cable TV, Internet, Wifi, Air conditionin...   56.00
# 28  [Wifi, Air conditioning, Kitchen, Free parking...  110.00
# 29  [Wifi, Kitchen, Free street parking, Heating, ...   81.00
# 30  [Wifi, Kitchen, Free parking on premises, Buzz...   55.00
# 31  [TV, Wifi, Air conditioning, Kitchen, Heating,...  119.00
# 32  [TV, Wifi, Air conditioning, Kitchen, Free par...  190.00
# 33  [TV, Wifi, Air conditioning, Kitchen, Free par...  127.00
# 34  [TV, Cable TV, Wifi, Kitchen, Paid parking off...   40.00
# 35  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...  160.00
# 36  [TV, Wifi, Kitchen, Free parking on premises, ...   95.00
# 37  [TV, Cable TV, Wifi, Air conditioning, Kitchen...  110.00
# 38  [TV, Wifi, Air conditioning, Kitchen, Free par...  149.00
# 39  [TV, Cable TV, Internet, Wifi, Wheelchair acce...  100.00
# 40  [Internet, Wifi, Kitchen, Free parking on prem...   95.00
# 41  [TV, Wifi, Kitchen, Free parking on premises, ...  221.00
# 42  [TV, Internet, Wifi, Kitchen, Other pet(s), In...  495.00
# 43  [TV, Cable TV, Internet, Wifi, Kitchen, Free p...  275.00
# 44  [TV, Wifi, Kitchen, Free street parking, Heati...  129.00
# 45  [TV, Cable TV, Wifi, Air conditioning, Pool, K...  387.00
# 46  [TV, Internet, Wifi, Air conditioning, Pool, K...  299.00
#
#    security_deposit cleaning_fee extra_people guests_included  \
# 0            100.00        15.00         8.00               4
# 1            136.00        50.00        25.00               2
# 2            120.00         7.00        10.00               1
# 3              0.00         0.00         0.00               1
# 4           1999.00       290.00         0.00               1
# 5               NaN        20.00         8.00               4
# 6            200.00        50.00         7.00               2
# 7               NaN          NaN         0.00               1
# 8            100.00        69.00         0.00               1
# 9               NaN          NaN        25.00               2
# 10           135.00        50.00        30.00               2
# 11              NaN        63.00         0.00               1
# 12             0.00        90.00         0.00               4
# 13           500.00        80.00        10.00               1
# 14             0.00         6.00         0.00               1
# 15              NaN        35.00        25.00               2
# 16           100.00        23.00        15.00               2
# 17           500.00       140.00         0.00               1
# 18           150.00        30.00        50.00               2
# 19           200.00       120.00         0.00               1
# 20           450.00        91.00        15.00               6
# 21             0.00        95.00        20.00               4
# 22           150.00        35.00        15.00               4
# 23             0.00        48.00         0.00               1
# 24              NaN        50.00         0.00               1
# 25             0.00        15.00        15.00               1
# 26           150.00         0.00         0.00               2
# 27           344.00        51.00         7.00               2
# 28              NaN          NaN         0.00               1
# 29              NaN        30.00        15.00               4
# 30             0.00        20.00        15.00               2
# 31             0.00        75.00        20.00               6
# 32             0.00        50.00        50.00               2
# 33             0.00        40.00        30.00               2
# 34           500.00         0.00         0.00               1
# 35          1000.00       350.00        10.00               3
# 36             0.00        35.00         0.00               1
# 37             0.00        25.00        15.00               4
# 38           250.00        69.00        20.00               4
# 39              NaN       100.00         0.00               1
# 40              NaN          NaN         0.00               1
# 41              NaN        50.00         0.00               1
# 42              NaN       150.00         0.00               1
# 43           500.00       125.00         0.00               1
# 44             0.00         0.00         0.00               1
# 45             0.00       175.00        10.00               6
# 46          1500.00       210.00         0.00               1
#
#                                               address  \
# 0   {'street': 'Barcelona, Catalonia, Spain', 'sub...
# 1   {'street': 'Balgowlah, NSW, Australia', 'subur...
# 2   {'street': 'Montréal, Québec, Canada', 'suburb...
# 3   {'street': 'Porto, Porto, Portugal', 'suburb':...
# 4   {'street': 'McMahons Point, NSW, Australia', '...
# 5   {'street': 'Porto, Porto, Portugal', 'suburb':...
# 6   {'street': 'Montréal, Québec, Canada', 'suburb...
# 7   {'street': 'Barcelona, Catalunya, Spain', 'sub...
# 8   {'street': 'Honolulu, HI, United States', 'sub...
# 9   {'street': 'Brooklyn, NY, United States', 'sub...
# 10  {'street': 'Sydney Olympic Park, NSW, Australi...
# 11  {'street': 'Montréal, Québec, Canada', 'suburb...
# 12  {'street': 'Montréal, Québec, Canada', 'suburb...
# 13  {'street': 'Randwick, NSW, Australia', 'suburb...
# 14  {'street': 'Hampstead, Québec, Canada', 'subur...
# 15  {'street': 'Montréal, Québec, Canada', 'suburb...
# 16  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 17  {'street': 'Randwick, NSW, Australia', 'suburb...
# 18  {'street': 'Montréal, Québec, Canada', 'suburb...
# 19  {'street': 'Manly, NSW, Australia', 'suburb': ...
# 20  {'street': 'Montréal, Québec, Canada', 'suburb...
# 21  {'street': 'Montréal, Québec, Canada', 'suburb...
# 22  {'street': 'Canidelo, Vila Nova de Gaia, Portu...
# 23  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 24  {'street': 'Saint Peters, NSW, Australia', 'su...
# 25  {'street': 'Montréal, Québec, Canada', 'suburb...
# 26  {'street': 'Montréal, Québec, Canada', 'suburb...
# 27  {'street': 'Montréal, Québec, Canada', 'suburb...
# 28  {'street': 'Montréal, Québec, Canada', 'suburb...
# 29  {'street': 'Montréal, QC, Canada', 'suburb': '...
# 30  {'street': 'Porto, Porto District, Portugal', ...
# 31  {'street': 'Montréal, Québec, Canada', 'suburb...
# 32  {'street': 'Dee Why, NSW, Australia', 'suburb'...
# 33  {'street': 'Montréal, Québec, Canada', 'suburb...
# 34  {'street': 'Vila Nova de Gaia, Porto, Portugal...
# 35  {'street': 'Honolulu, HI, United States', 'sub...
# 36  {'street': 'Montréal, Québec, Canada', 'suburb...
# 37  {'street': 'Montréal, Québec, Canada', 'suburb...
# 38  {'street': 'Montréal, Québec, Canada', 'suburb...
# 39  {'street': 'Freshwater, NSW, Australia', 'subu...
# 40  {'street': 'Montréal, Québec, Canada', 'suburb...
# 41  {'street': 'Beşiktaş, İstanbul, Turkey', 'subu...
# 42  {'street': 'Randwick, NSW, Australia', 'suburb...
# 43  {'street': 'Honolulu, HI, United States', 'sub...
# 44  {'street': 'Glebe, NSW, Australia', 'suburb': ...
# 45  {'street': 'Carlton, NSW, Australia', 'suburb'...
# 46  {'street': 'Woolloomooloo, NSW, Australia', 's...
#
#                                         review_scores  \
# 0   {'review_scores_accuracy': 9, 'review_scores_c...
# 1   {'review_scores_accuracy': 10, 'review_scores_...
# 2                                                 NaN
# 3   {'review_scores_accuracy': 10, 'review_scores_...
# 4   {'review_scores_accuracy': 10, 'review_scores_...
# 5   {'review_scores_accuracy': 9, 'review_scores_c...
# 6   {'review_scores_accuracy': 10, 'review_scores_...
# 7   {'review_scores_accuracy': 9, 'review_scores_c...
# 8   {'review_scores_accuracy': 10, 'review_scores_...
# 9   {'review_scores_accuracy': 10, 'review_scores_...
# 10  {'review_scores_accuracy': 9, 'review_scores_c...
# 11  {'review_scores_accuracy': 9, 'review_scores_c...
# 12  {'review_scores_accuracy': 10, 'review_scores_...
# 13  {'review_scores_accuracy': 9, 'review_scores_c...
# 14  {'review_scores_accuracy': 10, 'review_scores_...
# 15  {'review_scores_accuracy': 9, 'review_scores_c...
# 16  {'review_scores_accuracy': 9, 'review_scores_c...
# 17  {'review_scores_accuracy': 10, 'review_scores_...
# 18  {'review_scores_accuracy': 10, 'review_scores_...
# 19  {'review_scores_accuracy': 9, 'review_scores_c...
# 20  {'review_scores_accuracy': 9, 'review_scores_c...
# 21  {'review_scores_accuracy': 10, 'review_scores_...
# 22  {'review_scores_accuracy': 10, 'review_scores_...
# 23  {'review_scores_accuracy': 8, 'review_scores_c...
# 24  {'review_scores_accuracy': 10, 'review_scores_...
# 25  {'review_scores_accuracy': 10, 'review_scores_...
# 26                                                NaN
# 27  {'review_scores_accuracy': 10, 'review_scores_...
# 28  {'review_scores_accuracy': 10, 'review_scores_...
# 29  {'review_scores_accuracy': 10, 'review_scores_...
# 30  {'review_scores_accuracy': 10, 'review_scores_...
# 31  {'review_scores_accuracy': 10, 'review_scores_...
# 32  {'review_scores_accuracy': 10, 'review_scores_...
# 33  {'review_scores_accuracy': 10, 'review_scores_...
# 34  {'review_scores_accuracy': 10, 'review_scores_...
# 35                                                NaN
# 36  {'review_scores_accuracy': 10, 'review_scores_...
# 37  {'review_scores_accuracy': 10, 'review_scores_...
# 38                                                NaN
# 39                                                NaN
# 40  {'review_scores_accuracy': 8, 'review_scores_c...
# 41                                                NaN
# 42  {'review_scores_accuracy': 9, 'review_scores_c...
# 43  {'review_scores_accuracy': 9, 'review_scores_c...
# 44  {'review_scores_accuracy': 10, 'review_scores_...
# 45  {'review_scores_accuracy': 10, 'review_scores_...
# 46  {'review_scores_accuracy': 9, 'review_scores_c...
#
#                                               reviews weekly_price  \
# 0   [{'_id': '4329938', 'date': 2013-04-28 04:00:0...          NaN
# 1   [{'_id': '62053986', 'date': 2016-02-10 05:00:...          NaN
# 2   [{'_id': '106754307', 'date': 2016-10-07 04:00...          NaN
# 3   [{'_id': '79806675', 'date': 2016-06-14 04:00:...          NaN
# 4   [{'_id': '90127148', 'date': 2016-07-31 04:00:...          NaN
# 5   [{'_id': '86944847', 'date': 2016-07-18 04:00:...          NaN
# 6   [{'_id': '107430890', 'date': 2016-10-10 04:00...          NaN
# 7   [{'_id': '103371417', 'date': 2016-09-22 04:00...          NaN
# 8   [{'_id': '120473213', 'date': 2016-12-10 05:00...          NaN
# 9   [{'_id': '115682030', 'date': 2016-11-26 05:00...          NaN
# 10  [{'_id': '129279261', 'date': 2017-01-29 05:00...          NaN
# 11  [{'_id': '152644763', 'date': 2017-05-17 04:00...          NaN
# 12  [{'_id': '166527931', 'date': 2017-07-03 04:00...          NaN
# 13  [{'_id': '168126802', 'date': 2017-07-09 04:00...          NaN
# 14  [{'_id': '186142691', 'date': 2017-08-23 04:00...          NaN
# 15  [{'_id': '168529088', 'date': 2017-07-09 04:00...          NaN
# 16  [{'_id': '179819496', 'date': 2017-08-08 04:00...          NaN
# 17  [{'_id': '219779831', 'date': 2017-12-18 05:00...          NaN
# 18  [{'_id': '220955605', 'date': 2017-12-24 05:00...          NaN
# 19  [{'_id': '224691100', 'date': 2018-01-04 05:00...          NaN
# 20  [{'_id': '236523087', 'date': 2018-02-19 05:00...          NaN
# 21  [{'_id': '236522806', 'date': 2018-02-19 05:00...          NaN
# 22  [{'_id': '261445493', 'date': 2018-05-06 04:00...          NaN
# 23  [{'_id': '305563108', 'date': 2018-08-11 04:00...          NaN
# 24  [{'_id': '280718303', 'date': 2018-06-24 04:00...          NaN
# 25  [{'_id': '271869867', 'date': 2018-06-02 04:00...          NaN
# 26                                                NaN          NaN
# 27  [{'_id': '311576754', 'date': 2018-08-21 04:00...          NaN
# 28  [{'_id': '314241773', 'date': 2018-08-26 04:00...          NaN
# 29  [{'_id': '291337010', 'date': 2018-07-15 04:00...          NaN
# 30  [{'_id': '13119757', 'date': 2014-05-19 04:00:...          NaN
# 31  [{'_id': '359326246', 'date': 2018-12-16 05:00...          NaN
# 32  [{'_id': '366587275', 'date': 2019-01-02 05:00...          NaN
# 33  [{'_id': '357778221', 'date': 2018-12-11 05:00...          NaN
# 34  [{'_id': '362867135', 'date': 2018-12-27 05:00...          NaN
# 35                                                NaN          NaN
# 36  [{'_id': '359649347', 'date': 2018-12-17 05:00...          NaN
# 37  [{'_id': '419685257', 'date': 2019-03-04 05:00...          NaN
# 38                                                NaN          NaN
# 39                                                NaN       600.00
# 40  [{'_id': '41079717', 'date': 2015-08-04 04:00:...          NaN
# 41                                                NaN          NaN
# 42  [{'_id': '49176419', 'date': 2015-10-01 04:00:...      1850.00
# 43  [{'_id': '51172182', 'date': 2015-10-18 04:00:...          NaN
# 44  [{'_id': '61037346', 'date': 2016-01-31 05:00:...          NaN
# 45  [{'_id': '57967776', 'date': 2015-12-30 05:00:...      1750.00
# 46  [{'_id': '56751025', 'date': 2015-12-17 05:00:...          NaN
#
#    monthly_price
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42       7500.00
# 43           NaN
# 44           NaN
# 45       6000.00
# 46           NaN

# %% [markdown]
# 13. (bonus) Afficher le nom des logements ayant une lattitude comprise entre 36,1 et 40,6 dont le prix est entre 100 et 200 euros.

# %%
lat = db.airbnb.find({"address.location.coordinates.1": {"$gte": 36.1}, "address.location.coordinates.1": {"$lte": 40.6}, "price": {"$gte": 100}, "price": {"$lte": 200}}, {"_id": 0, "name": 1})
print(pd.DataFrame(list(lat)))
#Nous avons 47 logements contenant le mot "park"
# Out:
#                                                   name
# 0                         Copacabana Apartment Posto 6
# 1                     Ocean View Waikiki Marina w/prkg
# 2                    City center private room with bed
# 3                Makaha Valley Paradise with OceanView
# 4     Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                ...
# 1094                Copacabana a 3 quadras da praia :)
# 1095                           Magnificient Beach View
# 1096         Modern Diamond Head One Bedroom Apartment
# 1097  Qto Aconchegante no em frente ao Parque Olímpico
# 1098                                      Quarto Legal
#
# [1099 rows x 1 columns]
